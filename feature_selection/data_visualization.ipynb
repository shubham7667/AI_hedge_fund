# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_pickle('../Data/feature_added_data/binary_labelled_data.pkl')
data.head()
# Out:
# Price           Close       High        Low       Open     Volume    sma-5  \
# Date
# 2016-11-10  37.118999  38.941502  35.884998  38.940498  254940000      NaN
# 2016-11-11  36.950500  37.162998  36.445000  36.786499  132456000      NaN
# 2016-11-14  35.953499  37.299999  35.505001  37.275501  146426000      NaN
# 2016-11-15  37.161999  37.339001  36.299500  36.500000  135116000      NaN
# 2016-11-16  37.324501  37.493500  36.780499  36.993999   72976000  36.9019
#
# Price       sma-20  sma-50  Close-sma-50  sma_5-sma_20  ...  Rolling_std  \
# Date                                                    ...
# 2016-11-10     NaN     NaN           NaN           NaN  ...          NaN
# 2016-11-11     NaN     NaN           NaN           NaN  ...          NaN
# 2016-11-14     NaN     NaN           NaN           NaN  ...          NaN
# 2016-11-15     NaN     NaN           NaN           NaN  ...          NaN
# 2016-11-16     NaN     NaN           NaN           NaN  ...          NaN
#
# Price       Rolling_minimum_20  Rolling_maximum_20  Rolling_mean_20  \
# Date
# 2016-11-10                 NaN                 NaN              NaN
# 2016-11-11                 NaN                 NaN              NaN
# 2016-11-14                 NaN                 NaN              NaN
# 2016-11-15                 NaN                 NaN              NaN
# 2016-11-16                 NaN                 NaN              NaN
#
# Price       Gap_Return  RVOL  Volume_MA_20  Volume_Change  Tomorrow Close  \
# Date
# 2016-11-10         NaN   NaN           NaN            NaN       36.950500
# 2016-11-11   -0.008958   NaN           NaN   -122484000.0       35.953499
# 2016-11-14    0.008796   NaN           NaN     13970000.0       37.161999
# 2016-11-15    0.015200   NaN           NaN    -11310000.0       37.324501
# 2016-11-16   -0.004521   NaN           NaN    -62140000.0       37.820000
#
# Price       Label
# Date
# 2016-11-10      0
# 2016-11-11      0
# 2016-11-14      1
# 2016-11-15      1
# 2016-11-16      1
#
# [5 rows x 54 columns]

# %%
sns.histplot(data['Close'],kde=True)
# Out:
# <Axes: xlabel='Close', ylabel='Count'>
