# %%
import pandas as pd

# %%
data = pd.read_pickle('../Data/preprocessed_data/preprocessed_data.pkl')
data.head()
# Out:
# Price           Close       High        Low       Open    Volume      sma-5  \
# Date
# 2017-01-24  41.122002  41.199501  40.724998  41.099998  59434000  40.651701
# 2017-01-25  41.826000  41.870998  41.264500  41.289501  78452000  40.942101
# 2017-01-26  41.957500  42.192001  41.650002  41.776501  71726000  41.243201
# 2017-01-27  41.788502  41.985001  41.472000  41.950001  59974000  41.517601
# 2017-01-30  41.519001  41.674999  40.819000  41.650002  74946000  41.642601
#
# Price          sma-20    sma-50  Close-sma-50  sma_5-sma_20  ...  \
# Date                                                         ...
# 2017-01-24  39.509850  38.62706      2.494942      1.141851  ...
# 2017-01-25  39.699675  38.72120      3.104800      1.242426  ...
# 2017-01-26  39.869050  38.82134      3.136161      1.374151  ...
# 2017-01-27  40.028150  38.93804      2.850462      1.489451  ...
# 2017-01-30  40.191225  39.02518      2.493821      1.451376  ...
#
# Price       Rolling_mean_20  Rolling_maximum_20  Rolling_minimum_20  \
# Date
# 2017-01-24        39.509850           41.122002             37.4935
# 2017-01-25        39.699675           41.826000             37.4935
# 2017-01-26        39.869050           41.957500             37.4935
# 2017-01-27        40.028150           41.957500             37.4935
# 2017-01-30        40.191225           41.957500             37.4935
#
# Price       Rolling_std  rolling_volatility      RVOL  Volume_MA_20  \
# Date
# 2017-01-24     1.201074            0.011484  0.868399    68440900.0
# 2017-01-25     1.253656            0.011550  1.114662    70381900.0
# 2017-01-26     1.320073            0.011340  1.005559    71329500.0
# 2017-01-27     1.351282            0.011471  0.844381    71027200.0
# 2017-01-30     1.322853            0.011330  1.046495    71616200.0
#
# Price       Volume_Change  Tomorrow Close  Label
# Date
# 2017-01-24      3484000.0       41.826000      1
# 2017-01-25     19018000.0       41.957500      1
# 2017-01-26     -6726000.0       41.788502      0
# 2017-01-27    -11752000.0       41.519001      0
# 2017-01-30     14972000.0       41.174000      0
#
# [5 rows x 56 columns]

# %%
x = data.drop(columns=['Label'])
y = data['Label']

# %%
split_index = int(len(data)*0.8)
x_train= data[:split_index]
x_test=data[split_index:]

y_train=data[:split_index]
y_test = data[split_index:]

# %%
x_train.to_pickle('../Data/train_test_data/x_train.pkl')
y_train.to_pickle('../Data/train_test_data/y_train.pkl')
x_test.to_pickle('../Data/train_test_data/x_test.pkl')
y_test.to_pickle('../Data/train_test_data/y_test.pkl')
