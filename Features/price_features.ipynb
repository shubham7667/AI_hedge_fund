# %% [markdown]
# # PRICE FEATURES
#
# ##### daily, weekly , monthly , log returns

# %%
import pandas as pd
import os 
import numpy as np
import sys

# %%
data = pd.read_pickle('../Data/technical_indicator_data.pkl')
data.head()
# Out:
# Price           Close       High        Low       Open     Volume    sma-5  \
# Date
# 2016-11-10  37.118999  38.941502  35.884998  38.940498  254940000      NaN
# 2016-11-11  36.950500  37.162998  36.445000  36.786499  132456000      NaN
# 2016-11-14  35.953499  37.299999  35.505001  37.275501  146426000      NaN
# 2016-11-15  37.161999  37.339001  36.299500  36.500000  135116000      NaN
# 2016-11-16  37.324501  37.493500  36.780499  36.993999   72976000  36.9019
#
# Price       sma-20  sma-50  Close-sma-50  sma_5-sma_20  ...        OBV  \
# Date                                                    ...
# 2016-11-10     NaN     NaN           NaN           NaN  ...          0
# 2016-11-11     NaN     NaN           NaN           NaN  ... -132456000
# 2016-11-14     NaN     NaN           NaN           NaN  ... -278882000
# 2016-11-15     NaN     NaN           NaN           NaN  ... -143766000
# 2016-11-16     NaN     NaN           NaN           NaN  ...  -70790000
#
# Price            VWAP         tp           RMF   positive_mf   negative_mf  \
# Date
# 2016-11-10  37.315166  37.315166  9.513129e+09  0.000000e+00  0.000000e+00
# 2016-11-11  37.157088  36.852833  4.881379e+09  0.000000e+00  4.881379e+09
# 2016-11-14  36.909053  36.252833  5.308357e+09  0.000000e+00  5.308357e+09
# 2016-11-15  36.913991  36.933500  4.990307e+09  4.990307e+09  0.000000e+00
# 2016-11-16  36.942074  37.199500  2.714671e+09  2.714671e+09  0.000000e+00
#
# Price       positive_mf_14  negative_mf_14  MFR  MFI
# Date
# 2016-11-10             NaN             NaN  NaN  NaN
# 2016-11-11             NaN             NaN  NaN  NaN
# 2016-11-14             NaN             NaN  NaN  NaN
# 2016-11-15             NaN             NaN  NaN  NaN
# 2016-11-16             NaN             NaN  NaN  NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Daily return
#
# ```
#  To calculate a daily return, you subtract the starting price from the closing price. Once you have that, you simply multiply by the number of shares you own. and if we want how much percentage returns then divide the result by prev close
# ```
# ``
# we can use pct_change in place of shift.
#
# def calculate_return(data):
#     data['alu'] =data['Close'].pct_change(periods=5)
# ``

# %%
def calculate_daily_return(data):
    data['Daily_return'] =( data['Close'] - data['Close'].shift(1))/data['Close'].shift(1)

# %% [markdown]
# ### Weekly Return

# %%
def calculate_weekly_return(data):
    data['Weekly_return'] = (data['Close'] - data['Close'].shift(5))/data['Close'].shift(5)

# %% [markdown]
# ### Monthly Return

# %%
def calculate_monthly_return(data):
    data['Monthly_return'] = (data['Close']-data['Close'].shift(21))/data['Close'].shift(21)

# %% [markdown]
# ### Log Return

# %%
def log_return(data):
    data['Log_return']= np.log(
        data['Close']/data['Close'].shift(1)
    )

# %% [markdown]
# ### close-open

# %%
def calculate_close_open_diff(data):
 data['close-open'] = data['Close']-data['Open']

# %% [markdown]
# ### High - Low

# %%
def calculate_high_low_diff(data):
    data['high-low'] = data['High']-data['Low']

# %% [markdown]
# ### Gap up
# Today's Open > Yesterday's Close

# %%
def calculate_gapup(data):
    data["Gap_Return"]= (data['Open']-data['Close'].shift(1))/data['Close'].shift(1)

# %% [markdown]
# ### Rolling Mean (20)

# %%
def rolling_mean(data):
    data['Rolling_mean_20'] = data['Close'].rolling(window=20).mean()

# %% [markdown]
# ### Rolling Maximum (20)

# %%
def rolling_maximum(data):
    data['Rolling_maximum_20'] = data['Close'].rolling(window=20).max()

# %% [markdown]
# ### Rolling Minimum (20)

# %%
def rolling_minimum(data):
    data['Rolling_minimum_20'] = data['Close'].rolling(window=20).min()

# %% [markdown]
# ### Rolling Standard Deviation

# %%
def rolling_std(data):
    data['Rolling_std'] = data['Close'].rolling(window=20).std()

# %% [markdown]
# ### Rolling Volatility

# %%
def rolling_volatility(data):
    data['rolling_volatility'] = data['Daily_return'].rolling(window=20).std()

# %%
rolling_volatility(data)
rolling_std(data)
rolling_minimum(data)
rolling_maximum(data)
rolling_mean(data)
calculate_gapup(data)
log_return(data)
calculate_monthly_return(data)
calculate_weekly_return(data)
calculate_daily_return(data)

# %%
data.to_pickle('../Data/price_featured_data.pkl')
